# %% [markdown]
# # import dependencies

# %%
import sys, re
sys.path.append("../code-python3")
import csv

import matplotlib.pyplot as plt
from collections import Counter
import math, random, csv, json, re

from bs4 import BeautifulSoup
import requests
from dateutil.parser import parse

from twython import TwythonStreamer

# %% [markdown]
# # Reading Files

# %%
file_for_reading = open('../code-python3/stocks.txt', 'r')

# %%
file_for_reading.close()

# %%
start_with_hash = 0
with open('../code-python3/stocks.txt', 'r') as f:
    for line in f:
        if re.search("26.9", line):
            start_with_hash += 1

print(start_with_hash)
# Out:
# 20

# %% [markdown]
# # Delimited Files

# %%
def process(date, symbol, price):
    print(date, symbol, price)

print("tab delimited stock prices:")

with open('../code-python3/tab_delimited_stock_prices.txt', 'r', encoding='utf8',newline='') as f:
    reader = csv.reader(f, delimiter='\t')
    # reader = csv.reader(codecs.iterdecode(f, 'utf-8'), delimiter='\t')
    for row in reader:
        date = row[0]
        symbol = row[1]
        closing_price = float(row[2])
        process(date, symbol, closing_price)

print()

print("colon delimited stock prices:")

with open('../code-python3/colon_delimited_stock_prices.txt', 'r', encoding='utf8',newline='') as f:
    reader = csv.DictReader(f, delimiter=':')
    # reader = csv.DictReader(codecs.iterdecode(f, 'utf-8'), delimiter=':')
    for row in reader:
        date = row["date"]
        symbol = row["symbol"]
        closing_price = float(row["closing_price"])
        process(date, symbol, closing_price)

print()

print("writing out comma_delimited_stock_prices.txt")

today_prices = { 'AAPL' : 90.91, 'MSFT' : 41.68, 'FB' : 64.5 }

with open('../code-python3/comma_delimited_stock_prices.txt','w', encoding='utf8',newline='') as f:
    writer = csv.writer(f, delimiter=',')
    for stock, price in today_prices.items():
        writer.writerow([stock, price])
# Out:
# tab delimited stock prices:
# 6/20/2014 AAPL 90.91
# 6/20/2014 MSFT 41.68
# 6/20/2014 FB 64.5
# 6/19/2014 AAPL 91.86
# 6/19/2014 MSFT 41.51
# 6/19/2014 FB 64.34
#
# colon delimited stock prices:
# 6/20/2014 AAPL 90.91
# 6/20/2014 MSFT 41.68
# 6/20/2014 FB 64.5
#
# writing out comma_delimited_stock_prices.txt

# %% [markdown]
# # Scraping the Web

# %%
# there is AJAX call to perform the actual search for the book,
# so the BeautifulSoup cannot get any book info.

print("BeautifulSoup")
html = requests.get("http://shop.oreilly.com/category/browse-subjects/" + \
           "data.do?sortby=publicationDate&page=1").text
soup = BeautifulSoup(html)
print(soup)
print()
# Out:
# BeautifulSoup
# <!--[if IE]><![endif]--><!DOCTYPE html>
# <!--[if lt IE 9]><meta http-equiv="refresh" content="0; url=/unsupported-browser/" /><![endif]--><!--[if lt IE 10]><html class="no-js ie8 oldie" lang="en" prefix="og: http://ogp.me/ns/# og:book: http://ogp.me/ns/book# og:video: http://ogp.me/ns/video#" data-login-url="/accounts/login/"
# data-offline-url="/"
# data-url="/search/"
# data-csrf-cookie="csrfsafari"
# data-highlight-privacy="" data-debug=0 data-testing=0><![endif]--><!--[if gt IE 9]><!--><html class="no-js" data-csrf-cookie="csrfsafari" data-debug="0" data-highlight-privacy="" data-login-url="/accounts/login/" data-offline-url="/" data-testing="0" data-url="/search/" lang="en" prefix="og: http://ogp.me/ns/# og:book: http://ogp.me/ns/book# og:video: http://ogp.me/ns/video#"><!--<![endif]--><head><title>Search for : Safari</title><meta content="Search for : Safari" name="description"/><link href="https://www.oreilly.com/favicon.ico" rel="shortcut icon"/><meta charset="utf-8"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="Safari Books Online" name="author"/><meta content="telephone=no" name="format-detection"/><meta content="on" http-equiv="cleartype"/><meta content="True" name="HandheldFriendly"/><meta content="320" name="MobileOptimized"/><meta content="app-id=881697395, app-argument=safaridetail://" name="apple-itunes-app"/><meta content="width=device-width, minimum-scale=1.0, initial-scale=1.0" name="viewport"/><meta content="4503599627559754" property="twitter:account_id"/><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQQDUVVVGwACU1RUAQA="};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(20),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{h?h-=1:o(c||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(21),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",h=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(h+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&h>0&&(h-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,S=y.hash,this[u]=b.now()}function o(){M--,y.hash!==S&&i(0,!0);var t=b.now();this[l]=~~this[l]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=b.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,p="cb"+c,h="cb"+s,l="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,b=t("loader");if(w[v]&&b.xhrWrappable){var g=t(10),x=t(11),E=t(8),P=t(6),O=t(13),R=t(7),T=t(14),L=t(9),j=t("ee"),N=j.get("tracer");t(15),b.features.spa=!0;var S,M=0;j.on(u,r),j.on(p,r),j.on(d,o),j.on(h,o),j.buffer([u,d,"xhr-done","xhr-resolved"]),P.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),T.buffer([u,"new-xhr","send-xhr"+c]),R.buffer([m+c,m+"-done",m+f+c,m+f+s]),E.buffer(["newURL"]),g.buffer([u]),x.buffer(["propagate",p,h,"executor-err","resolve"+c]),N.buffer([u,"no-"+u]),L.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,"send-xhr"+c),a(j,"xhr-resolved"),a(j,"xhr-done"),a(R,m+c),a(R,m+"-done"),a(L,"new-js ...
#   (function(i,s,o,g,r,a,m) {
#     i['GoogleAnalyticsObject']=r;
#     i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();
#     a=s.createElement(o),m=s.getElementsByTagName(o)[0];
#     a.async=1;
#     a.src=g;
#     m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   var matches = document.cookie.match(/BrowserCookie\s*=\s*([a-f0-9\-]{36})/),
#       user_uuid = null;
#
#   if (matches && matches.length === 2) {
#     user_uuid = matches[1];
#   }
#
#
#   ga('create', 'UA-39299553-7');
#
#
#
#
#     ga('set', 'dimension1', 'Anonymous');
#
#
#
# ga('set', 'dimension6', user_uuid);
#
#
#
#
#
#
#
# //enable enhanced link tracking
# ga('require', 'linkid', 'linkid.js');
#
# // reading interface will track pageviews itself
# if (document.location.pathname.indexOf("/library/view") !== 0) {
#   ga('send', 'pageview');
# }
# </script><script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-5P4V6Z');
#   </script><script charset="utf-8" defer="" src="/jsi18n/web/"></script><script src="/static/js/src/modernizr.8e35451ddb64.js"></script><script>
#       var g = {};
#
#
#       window.SBO = {
#         "constants": {
#           "SEARCH_ENDPOINT": "https://www.safaribooksonline.com/api/v2/search/",
#           "SEARCH_SELECT_ENDPOINT": "https://www.safaribooksonline.com/api/v2/search/select/",
#           "SUGGEST_ENDPOINT": "https://www.safaribooksonline.com/api/v1/search/suggest/",
#           "REVIEWS_ENDPOINT": "https://www.safaribooksonline.com/api/v1/reviews/",
#           "REPORTS_ENDPOINT": "https://www.safaribooksonline.com/api/v1/reports/",
#           "REPORTS_BATCH_ENDPOINT": "https://www.safaribooksonline.com/api/v1/reports/batch/",
#           "ACADEMIC_INSTITUTION_ACCOUNT": "false",
#           "ENABLE_CASE_STUDIES": true,
#           "ENABLE_ONLINE_TRAINING": true,
#           "SELF_ASSESSMENT_SWITCH": "true"
#         }
#       };
#
#
#     </script><script type="application/javascript">
#
#             window.PUBLISHER_PAGES = true;
#
#     </script><script defer="" src="/static/js/build/vendor.4bb90b301ddb.js"></script><script defer="" src="/static/js/build/facetInit.0132fab972b5.js"></script></head><body class="sidenav nav-collapsed grid2 search-result-page facet-search-page js-facet-search-page js-heron falcon-search "><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-5P4V6Z" style="display:none;visibility:hidden" width="0"></iframe></noscript><a class="orm-topbar" href="//www.oreilly.com/"><svg height="13" viewbox="0 0 60 10" width="78" xmlns="http://www.w3.org/2000/svg"><desc>O'Reilly logo</desc><polygon points="28.09 1.96 28.09 0.42 21.68 0.42 21.68 9.64 28.09 9.64 28.09 8.11 23.22 8.11 23.22 5.8 27.86 5.8 27.86 4.27 23.22 4.27 23.22 1.96 28.09 1.96"></polygon><polygon points="32.85 9.64 32.85 0.42 34.39 0.42 34.39 8.11 38.82 8.11 38.82 9.64 32.85 9.64"></polygon><polygon points="40.07 9.64 40.07 0.42 41.61 0.42 41.61 8.11 46.04 8.11 46.04 9.64 40.07 9.64"></polygon><rect height="9.22" width="1.54" x="29.71" y="0.42"></rect><path d="M1.59,6.28a4.8,4.8,0,1,1,4.8,4.8,4.8,4.8,0,0,1-4.8-4.8M4.09,4A3.27,3.27,0,1,0,6.4,3,3.27,3.27,0,0,0,4.09,4" transform="translate(-1.59 -1.2)"></path><path d="M19.82,6.89A2.69,2.69,0,0,0,19,1.62H14.41v9.22h1.54V7h2.14l2.32,3.84H22.2ZM15.95,5.47V3.16H19a1.15,1.15,0,0,1,0,2.31h-3.1Z" transform="translate(-1.59 -1.2)"></path><path d="M13.32,2.61a1.13,1.13,0,1,1-1.13-1.13,1.13,1.13,0,0,1,1.13,1.13" transform="translate(-1.59 -1.2)"></path><polygon points="52.9 0.42 51.03 0.42 48.66 3.85 46.3 0.42 44.43 0.42 47.89 5.44 47.89 9.64 49.43 9.64 49.43 5.44 52.9 0.42"></polygon><path d="M58.31,1.2a2.41,2.41,0,1,0,2.41,2.42A2.42,2.42,0,0,0,58.31,1.2m0,4.44a2,2,0,1,1,2-2,2,2,0,0,1-2,2" transform="translate(-1.59 -1.2)"></path><path d="M59.4,3.09a0.72,0.72,0,0,0-.72-0.72H57.32V4.83h0.41v-1h0.69l0.49,1h0.46l-0.51-1a0.71,0.71,0,0,0,.54-0.69m-1.67-.31h0.95a0.31,0.31,0,0,1,.31.31,0.31,0.31,0,0,1-.31.3H57.73V2.78Z" transform="translate(-1.59 -1.2)"></path></svg></a><a class="skip" href="#page-title">Skip to content</a><header class="topbar t-topbar"><nav class="js-site-nav" role="navigation"><ul class="topnav"><li class="t-logo"><a class="l0 None safari-home nav-icn js-keyboard-nav-home" href="/"><svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><desc>Safari Home Icon</desc><g fill-rule="evenodd" stroke="none" stroke-width="1"><path d="M4 9.9L4 9.9 4 18 16 18 16 9.9 10 4 4 9.9ZM2.6 8.1L2.6 8.1 8.7 1.9 10 0.5 11.3 1.9 17.4 8.1 18 8.7 18 9.5 18 18.1 18 20 16.1 20 3.9 20 2 20 2 18.1 2 9.5 2 8.7 2.6 8.1Z"></path><rect height="7" width="3" x="10" y="12"></rect><rect height="2" transform="translate(18.121320, 10.121320) rotate(-315.000000) translate(-18.121320, -10.121320) " width="4" x="16.1" y="9.1"></rect><rect height="2" transform="translate(2.121320, 10.121320) scale(-1, 1) rotate(-315.000000) translate(-2.121320, -10.121320) " width="4" x="0.1" y="9.1"></rect></g></svg><span>Safari Home</span></a></li><li class="search"><a class="trigger ss-search l0 t-search-box" data-dropdown-selector=".searchbox" href="#"><span>Search</span></a></li><li class="usermenu dropdown"><a class="trigger l0 nav-icn nav-dropdown" href="#"><svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><desc>navigation arrow</desc><g fill-rule="evenodd" stroke="none" stroke-width="1"><path d="M0.1 12.5L9.7 3.1C9.8 3 9.9 3 10 3 10.1 3 10.2 3 10.3 3.1L19.9 12.5C20 12.5 20 12.6 20 12.8 20 12.9 20 13 19.9 13L17 15.9C16.9 16 16.8 16 16.7 16 16.5 16 16.4 16 16.4 15.9L10 9.7 3.6 15.9C3.6 16 3.5 16 3.3 16 3.2 16 3.1 16 3 15.9L0.1 13C0 12.9 0 12.8 0 12.7 0 12.7 0 12.6 0.1 12.5Z"></path></g></svg><span>Expand Nav</span></a><div class="drop-content"><ul><li id="nav-topics"><a class="t-topics-link l1 nav-icn" href="/learn/"><svg fill="#4A3C31" height="20" version="1.1" viewbox="0 0 50 55" width="20" xmlns="http://www.w3.org/2000/svg"><desc>topics ...
# <header id="lead">
# <ul>
# </ul>
# </header>
# <!--[if lt IE 9]>
#
# <![endif]-->
# <script defer="" src="/static/js/build/djangoMessagesPage.06917707eab1.js"></script>
# <div class="facets-form arriving search-page js-is-falcon-search" id="js-faceted-search">
# <div id="js-results-count-region">
# <!-- results count rendered here -->
# </div>
# <div id="search-layout">
# <div class="wrap-search-form">
# <div class="inner-search-form">
# <div id="js-search-form-region">
# <!-- search box with autocomplete rendered here -->
# </div>
# </div>
# </div>
# <div class="facets" id="js-facets">
# <span class="js-calculate-text hidden"></span>
# <div class="inline text">Showing</div>
# <div class="item inline js-facet-item js-media-facets">
# <input autocomplete="off" class="js-select-facet facet-input" data-placeholder="all media" data-type="format" placeholder="all media" tabindex="2"/>
# <div id="js-media-facets-region">
# <!-- media facets rendered here -->
# </div>
# <div class="active-facets-region" id="js-active-media-facets-region">
# <!-- active media facets rendered here -->
# </div>
# </div>
# <div class="inline text">in</div>
# <div class="item inline js-facet-item js-topics-facets">
# <input autocomplete="off" class="js-select-facet facet-input" data-placeholder="all topics" data-type="topics" placeholder="all topics" tabindex="3"/>
# <div id="js-topic-facets-region">
# <!-- topic facets rendered here -->
# </div>
# <div class="active-facets-region" id="js-active-topic-facets-region">
# <!-- active topic facets rendered here -->
# </div>
# </div>
# <div class="inline text">from</div>
# <div class="item inline js-facet-item js-publisher-facets">
# <input autocomplete="off" class="js-select-facet facet-input" data-placeholder="all publishers" data-type="publishers_exact" placeholder="all publishers" tabindex="4"/>
# <div id="js-publisher-facets-region">
# <!-- publisher facets rendered here -->
# </div>
# <div class="active-facets-region" id="js-active-publisher-facets-region">
# <!-- active publisher facets rendered here -->
# </div>
# </div>
# <div class="inline text">sorted by</div>
# <div class="item inline sort">
# <select id="id_sort js-sort-facets" name="sort">
# <option value="relevance">Relevance</option>
# <option value="popularity">Popularity</option>
# <option value="report_score">Rating</option>
# <option value="date_added">Date Added</option>
# <option value="publication_date">Publication Date</option>
# </select>
# </div>
# </div>
# <div id="js-search-help-region">
# <!-- search help is rendered here -->
# </div>
# <div class="results-content">
# <div id="js-results-header-region">
# <!-- results header is rendered here -->
# </div>
# <div id="js-results-region">
# <div class="search-loading"></div>
# <!-- search results are rendered here -->
# </div>
# <div id="js-pagination-region">
# <!-- pagination is rendered here -->
# </div>
# </div>
# </div>
# </div>
# <div id="js-ratings-modal-region">
# <!-- Ratings modal rendered here via js -->
# </div>
# <div class="chat-wrapper t-sales-chat">
# <!-- Begin Button Code.  Paste this code where you want the chat button to appear. -->
# <div class="live-agent" id="liveagent_button_online_573000000008OVU" style=" display: none ">
# <input class="button positive sales-chat-btn form-submit" onclick="liveagent.startChat('573000000008OVU')" style="" type="submit" value="Want Safari for teams? Chat with Sales"/>
# </div>
# <script src="/static/js/src/liveagent_deployment.min.js"></script>
# <script type="text/javascript">
#       if (!window._laq) { window._laq = []; }
#       window._laq.push(function(){
#         liveagent.showWhenOnline('573000000008OVU', document.getElementById('liveagent_button_online_573000000008OVU'));
#       });
#       if (liveagent) {
#         liveagent.init('https://d.la1a1.salesforceliveagent.com/chat', '572000000008OUl', '00D00000000hgdL');
#       }
#     </script>
# <!-- End Button Code -->
# </div> <!-- End chat-wrapper -->
# <div class="subscribe-nag clearfix app-panel anon-panel t-subscribe-nag" id="js-subscribe-nag">
# <div class="sample-message">
# <h2 class="t-nag-heading">Get Instant Access Now</h2>
# <div class="cta-group t-cta-group">
# <!-- always display calls to action -->
# <a class="button-primary t-nag-cta" href="/register/">Start a Free Trial</a>
# <div class="text-links">
# <span class="business-link">Learn about <a class="js-safari-for-business" href="/team-setup/">Safari for Business</a></span> <br/>
# <span class="signin">Have an account? <a class="t-preview-signin" href="/accounts/login/?next=/search/%3Fquery%3Ddata">Sign in.</a></span>
# </div>
# </div>
# </div>
# </div>
# <footer class="pagefoot">
# <a class="icon-up" href="#"><div class="visuallyhidden">Back to top</div></a>
# <ul class="js-footer-nav">
# <li class="full-support"><a href="https://www.safaribooksonline.com/public/support">Support</a></li>
# <li><a href="https://www.safaribooksonline.com/apps/">Get the App</a></li>
# <li><a href="/accounts/login/">Sign In</a></li>
# </ul>
# <span class="copyright">© 2018 <a href="https://www.safaribooksonline.com" target="_blank">Safari</a>.</span>
# <a href="/terms/">Terms of Service</a> /
#     <a href="/membership-agreement/">Membership Agreement</a> /
#     <a href="/privacy/">Privacy Policy</a>
# </footer>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam.nr-data.net","transactionName":"YgdaZ0NSW0cEB0RdWltNfkZfUEFdCgofXFBHDVYdR1pQQxZeVlVWUBZdV25AUFUXB1g=","licenseKey":"510f1a6865","applicationTime":108,"applicationID":"3275661","agent":"","beacon":"bam.nr-data.net","queueTime":0}</script>
# </article>
# </div>
# </body>
# </html>
#
# ()

# %% [markdown]
# # Books about Data

# %%
######
#
# BOOKS ABOUT DATA
#
######

def is_video(result):
    """it's a video if it has exactly one pricelabel, and if
    the stripped text inside that pricelabel starts with 'Video'"""
    return (result['format'] == 'video')

def book_info(result):
    title = result['title']
    authors = result['authors']
    isbn = result.get('isbn')
    date = result['issued']

    return {
        "title" : title,
        "authors" : authors,
        "isbn" : isbn,
        "date" : date
    }

from time import sleep

def scrape(num_pages=31):
    
    books = []
    for page_num in range(0, num_pages):
        response = requests.post('https://www.safaribooksonline.com/api/v2/search/', data = {'query':'data', 'page': page_num})
        print("souping page", page_num)
        
        # print("response.text", response.text)
        
        booksjson = json.loads(response.text)
        results = booksjson['results']
        
        for result in results:
            if not is_video(result):
                books.append(book_info(result))
        
        if (page_num + 1 != num_pages):
            sleep(5)
        

    return books

def get_year(book):
    return int(parse(book["date"]).year)

def plot_years(plt, books):
    # 2014 is the last complete year of data (when I ran this)
    year_counts = Counter(get_year(book) for book in books)

    years = sorted(year_counts)
    book_counts = [year_counts[year] for year in years]
    plt.bar([x - 0.5 for x in years], book_counts)
    plt.xlabel("year")
    plt.ylabel("# of data books")
    plt.title("Data is Big!")
    plt.show()

    

books = scrape(num_pages=31)
books
plot_years(plt, books)
# Out:
# ('souping page', 0)
# ('souping page', 1)
# ('souping page', 2)
# ('souping page', 3)
# ('souping page', 4)
# ('souping page', 5)
# ('souping page', 6)
# ('souping page', 7)
# ('souping page', 8)
# ('souping page', 9)
# ('souping page', 10)
# ('souping page', 11)
# ('souping page', 12)
# ('souping page', 13)
# ('souping page', 14)
# ('souping page', 15)
# ('souping page', 16)
# ('souping page', 17)
# ('souping page', 18)
# ('souping page', 19)
# ('souping page', 20)
# ('souping page', 21)
# ('souping page', 22)
# ('souping page', 23)
# ('souping page', 24)
# ('souping page', 25)
# ('souping page', 26)
# ('souping page', 27)
# ('souping page', 28)
# ('souping page', 29)
# ('souping page', 30)

# %%
print("parsing json")

serialized = """{ "title" : "Data Science Book",
                  "author" : "Joel Grus",
                  "publicationYear" : 2014,
                  "topics" : [ "data", "science", "data science"] }"""


# parse the JSON to create a Python object
deserialized = json.loads(serialized)
if "data science" in deserialized["topics"]:
    print(deserialized)

print()
# Out:
# parsing json
# {u'publicationYear': 2014, u'author': u'Joel Grus', u'topics': [u'data', u'science', u'data science'], u'title': u'Data Science Book'}
# ()

# %% [markdown]
# # Using an Unauthenticated API

# %%
##
#
# APIs
#
##

endpoint = "https://api.github.com/users/almandsky/repos"

repos = json.loads(requests.get(endpoint).text)


dates = [parse(repo["created_at"]) for repo in repos]
month_counts = Counter(date.month for date in dates)
weekday_counts = Counter(date.weekday() for date in dates)

print("GitHub API")
print("dates", dates)
print("month_counts", month_counts)
print("weekday_count", weekday_counts)

last_5_repositories = sorted(repos,
                             key=lambda r: r["created_at"],
                             reverse=True)[:5]

print("last five languages", [repo["language"]
                              for repo in last_5_repositories])
# Out:
# GitHub API
# ('dates', [datetime.datetime(2017, 8, 2, 5, 58, 24, tzinfo=tzutc()), datetime.datetime(2016, 11, 4, 6, 53, 36, tzinfo=tzutc()), datetime.datetime(2016, 2, 19, 21, 50, 8, tzinfo=tzutc()), datetime.datetime(2017, 6, 4, 7, 25, 58, tzinfo=tzutc()), datetime.datetime(2017, 11, 11, 4, 40, 56, tzinfo=tzutc()), datetime.datetime(2016, 11, 17, 8, 51, 47, tzinfo=tzutc()), datetime.datetime(2016, 9, 28, 0, 27, 56, tzinfo=tzutc()), datetime.datetime(2017, 8, 25, 18, 41, 22, tzinfo=tzutc()), datetime.datetime(2016, 9, 12, 20, 38, 40, tzinfo=tzutc()), datetime.datetime(2017, 8, 18, 17, 12, 36, tzinfo=tzutc()), datetime.datetime(2016, 9, 21, 17, 39, 9, tzinfo=tzutc()), datetime.datetime(2016, 7, 16, 9, 52, 9, tzinfo=tzutc()), datetime.datetime(2014, 3, 29, 8, 32, 49, tzinfo=tzutc()), datetime.datetime(2016, 6, 29, 6, 11, 23, tzinfo=tzutc()), datetime.datetime(2016, 6, 23, 0, 22, 13, tzinfo=tzutc()), datetime.datetime(2016, 6, 24, 7, 0, 14, tzinfo=tzutc()), datetime.datetime(2016, 9, 8, 22, 41, 9, tzinfo=tzutc()), datetime.datetime(2016, 5, 17, 0, 42, 29, tzinfo=tzutc()), datetime.datetime(2017, 8, 1, 15, 37, 42, tzinfo=tzutc()), datetime.datetime(2012, 5, 31, 6, 19, 32, tzinfo=tzutc()), datetime.datetime(2017, 9, 11, 7, 28, 26, tzinfo=tzutc()), datetime.datetime(2014, 3, 29, 8, 35, 27, tzinfo=tzutc()), datetime.datetime(2017, 9, 11, 6, 53, 29, tzinfo=tzutc()), datetime.datetime(2013, 2, 22, 5, 53, 17, tzinfo=tzutc()), datetime.datetime(2016, 8, 3, 6, 55, 39, tzinfo=tzutc()), datetime.datetime(2016, 8, 10, 8, 30, 6, tzinfo=tzutc()), datetime.datetime(2016, 10, 21, 5, 46, 38, tzinfo=tzutc()), datetime.datetime(2016, 3, 9, 16, 39, 58, tzinfo=tzutc()), datetime.datetime(2012, 6, 1, 6, 6, 51, tzinfo=tzutc()), datetime.datetime(2016, 10, 12, 8, 10, 51, tzinfo=tzutc())])
# ('month_counts', Counter({8: 6, 9: 6, 6: 5, 3: 3, 11: 3, 2: 2, 5: 2, 10: 2, 7: 1}))
# ('weekday_count', Counter({2: 8, 4: 8, 3: 4, 5: 4, 0: 3, 1: 2, 6: 1}))
# ('last five languages', [u'Jupyter Notebook', u'Jupyter Notebook', u'TypeScript', u'Jupyter Notebook', u'JavaScript'])

# %% [markdown]
# # Using the Twitter APIs

# %%
####
#
# Twitter
#
####

from twython import Twython

# fill these in if you want to use the code
CONSUMER_KEY = ""
CONSUMER_SECRET = ""
ACCESS_TOKEN = ""
ACCESS_TOKEN_SECRET = ""

def call_twitter_search_api():

    twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET)

    # search for tweets containing the phrase "data science"
    for status in twitter.search(q='"data science"')["statuses"]:
        user = status["user"]["screen_name"].encode('utf-8')
        text = status["text"].encode('utf-8')
        print(user, ":", text)
        print()



# appending data to a global variable is pretty poor form
# but it makes the example much simpler
tweets = []

class MyStreamer(TwythonStreamer):
    """our own subclass of TwythonStreamer that specifies
    how to interact with the stream"""

    def on_success(self, data):
        """what do we do when twitter sends us data?
        here data will be a Python object representing a tweet"""

        # print("data",data)
        # only want to collect English-language tweets
        # if data['lang'] == 'en':
        #     tweets.append(data)
        tweets.append(data)
        # stop when we've collected enough
        if len(tweets) >= 100:
            self.disconnect()

    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()

def call_twitter_streaming_api():
    stream = MyStreamer(CONSUMER_KEY, CONSUMER_SECRET,
                        ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

    # starts consuming public statuses that contain the keyword 'data'
    stream.statuses.filter(track='data')

# %%
call_twitter_search_api()
# Out:
# ('michel27014', ':', 'RT @Intellipaat: Upskill yourself to survive tech #layoffs Learn #BigData &amp; #DataScience from scratch to advance level. Here is the Right P\xe2\x80\xa6')
# ()
# ('abdulslam_z', ':', 'RT @Dr_Hmood: \xd8\xaa\xd9\x86\xd9\x88\xd9\x8a \xd8\xa7\xd9\x84\xd8\xaf\xd8\xae\xd9\x88\xd9\x84 \xd9\x84\xd8\xb9\xd8\xa7\xd9\x84\xd9\x85 \xd8\xb9\xd9\x84\xd9\x85 \xd8\xa7\xd9\x84\xd8\xa8\xd9\x8a\xd8\xa7\xd9\x86\xd8\xa7\xd8\xaa \xd9\x88\xd9\x84\xd8\xa7 \xd8\xaa\xd8\xb9\xd8\xb1\xd9\x81 \xd9\x83\xd9\x8a\xd9\x81 \xd8\xaa\xd8\xa8\xd8\xaf\xd8\xa3!\xf0\x9f\xa4\x94\n\xd8\xa3\xd8\xb3\xd9\x81\xd9\x84 \xd9\x87\xd8\xb0\xd9\x87 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xba\xd8\xb1\xd9\x8a\xd8\xaf\xd8\xa9 \xd8\xb3\xd8\xa3\xd8\xaa\xd9\x83\xd9\x84\xd9\x85 \xd8\xb9\xd9\x86 \xd8\xae\xd8\xa7\xd8\xb1\xd8\xb7\xd8\xa9 \xd8\xb7\xd8\xb1\xd9\x8a\xd9\x82 \xd8\xaa\xd8\xb5\xd9\x84\xd8\xad \xd9\x84\xd9\x85\xd9\x86 \xd9\x8a\xd9\x86\xd9\x88\xd9\x8a \xd8\xaa\xd8\xb9\xd9\x84\xd9\x85 \xd8\xb9\xd9\x84\xd9\x85 \xd8\xa7\xd9\x84\xd8\xa8\xd9\x8a\xd8\xa7\xd9\x86\xd8\xa7\xd8\xaa (Da\xe2\x80\xa6')
# ()
# ('BigBangFinger', ':', "RT @gp_pulipaka: ActiveState's #Python taps Intel MKL For #DataScience and #MachineLearning. #BigData #DeepLearning #AI #Theano \nhttps://t.\xe2\x80\xa6")
# ()
# ('Geobin63', ':', "RT @Unathi_Kwaza: Data science is in demand globally, but it's still not widely available as a field of study in SA,says Schwartzkopf.There\xe2\x80\xa6")
# ()
# ('100Hallow', ':', 'RT @python_devv: Pandas Data Science for Beginners\n\n\xe2\x98\x9e https://t.co/vBSdXLAxKQ\n\n#python #Pandas https://t.co/yjR8vJRrH5')
# ()
# ('homeAIinfo', ':', 'Data Mining and Data Science - Data Mining and Data Science. https://t.co/BulkznGxaW #data-science')
# ()
# ('Abinobaid', ':', 'RT @Dr_Hmood: \xd8\xaa\xd9\x86\xd9\x88\xd9\x8a \xd8\xa7\xd9\x84\xd8\xaf\xd8\xae\xd9\x88\xd9\x84 \xd9\x84\xd8\xb9\xd8\xa7\xd9\x84\xd9\x85 \xd8\xb9\xd9\x84\xd9\x85 \xd8\xa7\xd9\x84\xd8\xa8\xd9\x8a\xd8\xa7\xd9\x86\xd8\xa7\xd8\xaa \xd9\x88\xd9\x84\xd8\xa7 \xd8\xaa\xd8\xb9\xd8\xb1\xd9\x81 \xd9\x83\xd9\x8a\xd9\x81 \xd8\xaa\xd8\xa8\xd8\xaf\xd8\xa3!\xf0\x9f\xa4\x94\n\xd8\xa3\xd8\xb3\xd9\x81\xd9\x84 \xd9\x87\xd8\xb0\xd9\x87 \xd8\xa7\xd9\x84\xd8\xaa\xd8\xba\xd8\xb1\xd9\x8a\xd8\xaf\xd8\xa9 \xd8\xb3\xd8\xa3\xd8\xaa\xd9\x83\xd9\x84\xd9\x85 \xd8\xb9\xd9\x86 \xd8\xae\xd8\xa7\xd8\xb1\xd8\xb7\xd8\xa9 \xd8\xb7\xd8\xb1\xd9\x8a\xd9\x82 \xd8\xaa\xd8\xb5\xd9\x84\xd8\xad \xd9\x84\xd9\x85\xd9\x86 \xd9\x8a\xd9\x86\xd9\x88\xd9\x8a \xd8\xaa\xd8\xb9\xd9\x84\xd9\x85 \xd8\xb9\xd9\x84\xd9\x85 \xd8\xa7\xd9\x84\xd8\xa8\xd9\x8a\xd8\xa7\xd9\x86\xd8\xa7\xd8\xaa (Da\xe2\x80\xa6')
# ()
# ('khalil_hughes', ':', 'RT @machine_tuts: Data Science-Unsupervised Machine Learning Using R\n\n\xe2\x98\x9e https://t.co/izNMJJEMER\n\n#DataScience #MachineLearning https://t.co\xe2\x80\xa6')
# ()

# %%
call_twitter_streaming_api()

# %%
tweets
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:34 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 924361172,
#      u'id_str': u'924361172',
#      u'indices': [3, 17],
#      u'name': u'Craig Brown, PhD',
#      u'screen_name': u'craigbrownphd'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913134655070208,
#   u'id_str': u'949913134655070208',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'quote_count': 0,
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 06 21:57:05 +0000 2018',
#    u'display_text_range': [0, 140],
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/949761766141001728',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/lPcLWw90Tn'}],
#     u'user_mentions': []},
#    u'extended_tweet': {u'display_text_range': [0, 277],
#     u'entities': {u'hashtags': [{u'indices': [258, 266], u'text': u'BigData'},
#       {u'indices': [267, 277], u'text': u'Analytics'}],
#      u'media': [{u'display_url': u'pic.twitter.com/gF08kPGlmR',
#        u'expanded_url': u'https://twitter.com/craigbrownphd/status/949761766141001728/photo/1',
#        u'id': 949761762592608256,
#        u'id_str': u'949761762592608256',
#        u'indices': [278, 301],
#        u'media_url': u'http://pbs.twimg.com/media/DS47SoCU0AAEivE.jpg',
#        u'media_url_https': u'https://pbs.twimg.com/media/DS47SoCU0AAEivE.jpg',
#        u'sizes': {u'large': {u'h': 500, u'resize': u'fit', u'w': 700},
#         u'medium': {u'h': 500, u'resize': u'fit', u'w': 700},
#         u'small': {u'h': 486, u'resize': u'fit', u'w': 680},
#         u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#        u'type': u'photo',
#        u'url': u'https://t.co/gF08kPGlmR'}],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'goo.gl/4c9acu',
#        u'expanded_url': u'https://goo.gl/4c9acu',
#        u'indices': [234, 257],
#        u'url': u'https://t.co/MYxHB20Gg3'}],
#      u'user_mentions': []},
#     u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/gF08kPGlmR',
#        u'expanded_url': u'https://twitter.com/craigbrownphd/status/949761766141001728/photo/1',
#        u'id': 949761762592608256,
#        u'id_str': u'949761762592608256',
#        u'indices': [278, 301],
#        u'media_url': u'http://pbs.twimg.com/media/DS47SoCU0AAEivE.jpg',
#        u'media_url_https': u'https://pbs.twimg.com/media/DS47SoCU0AAEivE.jpg',
#        u'sizes': {u'large': {u'h': 500, u'resize': u'fit', u'w': 700},
#         u'medium': {u'h': 500, u'resize': u'fit', u'w': 700},
#         u'small': {u'h': 486, u'resize': u'fit', u'w': 680},
#         u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#        u'type': u'photo',
#        u'url': u'https://t.co/gF08kPGlmR'}]},
#     u'full_text': u'Behavioral Analysis of GitHub and StackOverflow Users: In this blog post, we will take a look at the activity on websites that became a significant part of development across all areas in, as well as, outside of Data Science:\xa0GitHub\u2026 https://t.co/MYxHB20Gg3 #BigData #Analytics https://t.co/gF08kPGlmR'},
#    u'favorite_count': 2,
#    u'favorited': False,
#    u'filter_level': u'low',
#    u'geo': None,
#    u'id': 949761766141001728,
#    u'id_str': u'949761766141001728',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'quote_count': 0,
#    u'reply_count': 0,
#    u'retweet_count': 225,
#    u'retweeted': False,
#    u'source': u'<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#    u'text': u'Behavioral Analysis of GitHub and StackOverflow Users: In this blog post, we will take a look at the activity on we\u2026 https://t.co/lPcLWw90Tn',
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Nov 04 01:00:05 +0000 2012',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'#Technology #Consultant (#techpreneur), #IT, #Data #Entrepreneur, #DataScience, #SME #CancerSurvivor #BigData #Cloud #AI #ML  https://github.com/craigbrownphd',
#     u'favourites_count': 11,
#     u'follow_request_sent': None,
#     u'followers_count': 216477,
#     u'following': None,
#     u'friends_count': 2105,
#     u'geo_enabled': False,
#     u'id': 924361172,
#     u'id_str': u'924361172',
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 397,
#     u'location': u'Houston, Chicago & Los Angeles',
#     u'name': u'Craig Brown, PhD',
#     u'notifications': None,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/924361172/1489272644',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/840559104082960384/gK874JNt_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/840559104082960384/gK874JNt_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'craigbrownphd',
#     u'statuses_count': 62993,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': u'http://www.craigbrownphd.com',
#     u'utc_offset': -28800,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u'RT @craigbrownphd: Behavioral Analysis of GitHub and StackOverflow Users: In this blog post, we will take a look at the activity on website\u2026',
#   u'timestamp_ms': u'1515311914491',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Tue Dec 26 06:58:28 +0000 2017',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': None,
#    u'favourites_count': 26,
#    u'follow_request_sent': None,
#    u'followers_count': 0,
#    u'following': None,
#    u'friends_count': 21,
#    u'geo_enabled': False,
#    u'id': 945549354156412928,
#    u'id_str': u'945549354156412928',
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 0,
#    u'location': None,
#    u'name': u'\u091a\u094c\u0927\u0930\u0940 \u0930\u093e\u091c\u0947\u0902\u0926\u094d\u0930 (\u091c\u093e\u091f)',
#    u'notifications': None,
#    u'profile_background_color': u'F5F8FA',
#    u'profile_background_image_url': u'',
#    u'profile_background_image_url_https': u'',
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/945550825392394240/hRc4LNRo_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/945550825392394240/hRc4LNRo_normal.jpg',
#    u'profile_link_color': u'1DA1F2',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'O7IdwekAMzG6lYJ',
#    u'statuses_count': 33,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:35 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913139193286657,
#   u'id_str': u'949913139193286657',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'quote_count': 0,
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u"Can there be a filter that removes anything Trump related \U0001f610, it's wasting my unlimited data",
#   u'timestamp_ms': u'1515311915573',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Dec 02 02:30:41 +0000 2016',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'Mentally unstable, but still doing better than you \U0001f61a',
#    u'favourites_count': 5382,
#    u'follow_request_sent': None,
#    u'followers_count': 71,
#    u'following': None,
#    u'friends_count': 119,
#    u'geo_enabled': False,
#    u'id': 804513085939654656,
#    u'id_str': u'804513085939654656',
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 0,
#    u'location': None,
#    u'name': u'Michael\u2122',
#    u'notifications': None,
#    u'profile_background_color': u'F5F8FA',
#    u'profile_background_image_url': u'',
#    u'profile_background_image_url_https': u'',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/804513085939654656/1513234088',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/946972744054460416/jG8BAqAX_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/946972744054460416/jG8BAqAX_normal.jpg',
#    u'profile_link_color': u'1DA1F2',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Gay_Coal',
#    u'statuses_count': 2527,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:35 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 287614755,
#      u'id_str': u'287614755',
#      u'indices': [3, 12],
#      u'name': u'el diablo',
#      u'screen_name': u'digembok'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913139449012225,
#   u'id_str': u'949913139449012225',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'in',
#   u'place': None,
#   u'quote_count': 0,
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sun Jan 07 04:30:24 +0000 2018',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/949860747248508929',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/PGidyFunPG'}],
#     u'user_mentions': []},
#    u'extended_tweet': {u'display_text_range': [0, 174],
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': []},
#     u'full_text': u'Bosen forensik MCA mulu. \nGue masih punya 60an data forensik.\nGimana kalo malem ini gue forensik TNI AU?\nSekalian tes skil...\nKalo setuju gue butuh 3333 RT\nKalo elo pada mau.'},
#    u'favorite_count': 202,
#    u'favorited': False,
#    u'filter_level': u'low',
#    u'geo': None,
#    u'id': 949860747248508929,
#    u'id_str': u'949860747248508929',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'place': None,
#    u'quote_count': 18,
#    u'reply_count': 121,
#    u'retweet_count': 1505,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'Bosen forensik MCA mulu. \nGue masih punya 60an data forensik.\nGimana kalo malem ini gue forensik TNI AU?\nSekalian t\u2026 https://t.co/PGidyFunPG',
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Apr 25 10:24:02 +0000 2011',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'filsuvisual yang rentan disesatkan',
#     u'favourites_count': 519,
#     u'follow_request_sent': None,
#     u'followers_count': 74413,
#     u'following': None,
#     u'friends_count': 339,
#     u'geo_enabled': False,
#     u'id': 287614755,
#     u'id_str': u'287614755',
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 250,
#     u'location': u'Patas 6A',
#     u'name': u'el diablo',
#     u'notifications': None,
#     u'profile_background_color': u'EDECE9',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme3/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme3/bg.gif',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/287614755/1480188742',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/857935256963264512/Hm5YoG5__normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/857935256963264512/Hm5YoG5__normal.jpg',
#     u'profile_link_color': u'088253',
#     u'profile_sidebar_border_color': u'D3D2CF',
#     u'profile_sidebar_fill_color': u'E3E2DE',
#     u'profile_text_color': u'634047',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'digembok',
#     u'statuses_count': 10980,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'translator_type': u'regular',
#     u'url': u'http://digembok.tumblr.com/',
#     u'utc_offset': -28800,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u'RT @digembok: Bosen forensik MCA mulu. \nGue masih punya 60an data forensik.\nGimana kalo malem ini gue forensik TNI AU?\nSekalian tes skil...\u2026',
#   u'timestamp_ms': u'1515311915634',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Tue Jun 08 18:13:12 +0000 2010',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'170 cm 60 kg 19 cm',
#    u'favourites_count': 402,
#    u'follow_request_sent': None,
#    u'followers_count': 26,
#    u'following': None,
#    u'friends_count': 87,
#    u'geo_enabled': False,
#    u'id': 153492453,
#    u'id_str': u'153492453',
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 0,
#    u'location': u'Mobile',
#    u'name': u'asusila',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/153492453/1397205099',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/528424508705615872/KE-rI8wn_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/528424508705615872/KE-rI8wn_normal.jpeg',
#    u'profile_link_color': u'1DA1F2',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'didiwahyoe',
#    u'statuses_count': 366,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:37 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/Wfvd3rm5qJ',
#      u'expanded_url': u'https://twitter.com/Tokyo_Trev/status/949724841984319489/photo/1',
#      u'id': 949724838515675136,
#      u'id_str': u'949724838515675136',
#      u'indices': [92, 115],
#      u'media_url': u'http://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#      u'sizes': {u'large': {u'h': 405, u'resize': u'fit', u'w': 720},
#       u'medium': {u'h': 405, u'resize': u'fit', u'w': 720},
#       u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 949724841984319489,
#      u'source_status_id_str': u'949724841984319489',
#      u'source_user_id': 108411936,
#      u'source_user_id_str': u'108411936',
#      u'type': u'photo',
#      u'url': u'https://t.co/Wfvd3rm5qJ'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 108411936,
#      u'id_str': u'108411936',
#      u'indices': [3, 14],
#      u'name': u'Trevor',
#      u'screen_name': u'Tokyo_Trev'}]},
#   u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/Wfvd3rm5qJ',
#      u'expanded_url': u'https://twitter.com/Tokyo_Trev/status/949724841984319489/photo/1',
#      u'id': 949724838515675136,
#      u'id_str': u'949724838515675136',
#      u'indices': [92, 115],
#      u'media_url': u'http://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#      u'sizes': {u'large': {u'h': 405, u'resize': u'fit', u'w': 720},
#       u'medium': {u'h': 405, u'resize': u'fit', u'w': 720},
#       u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'source_status_id': 949724841984319489,
#      u'source_status_id_str': u'949724841984319489',
#      u'source_user_id': 108411936,
#      u'source_user_id_str': u'108411936',
#      u'type': u'photo',
#      u'url': u'https://t.co/Wfvd3rm5qJ'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913145732096000,
#   u'id_str': u'949913145732096000',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'quote_count': 0,
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 06 19:30:22 +0000 2018',
#    u'display_text_range': [0, 75],
#    u'entities': {u'hashtags': [],
#     u'media': [{u'display_url': u'pic.twitter.com/Wfvd3rm5qJ',
#       u'expanded_url': u'https://twitter.com/Tokyo_Trev/status/949724841984319489/photo/1',
#       u'id': 949724838515675136,
#       u'id_str': u'949724838515675136',
#       u'indices': [76, 99],
#       u'media_url': u'http://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#       u'sizes': {u'large': {u'h': 405, u'resize': u'fit', u'w': 720},
#        u'medium': {u'h': 405, u'resize': u'fit', u'w': 720},
#        u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/Wfvd3rm5qJ'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/Wfvd3rm5qJ',
#       u'expanded_url': u'https://twitter.com/Tokyo_Trev/status/949724841984319489/photo/1',
#       u'id': 949724838515675136,
#       u'id_str': u'949724838515675136',
#       u'indices': [76, 99],
#       u'media_url': u'http://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/DS4ZtXIXkAA0qOO.jpg',
#       u'sizes': {u'large': {u'h': 405, u'resize': u'fit', u'w': 720},
#        u'medium': {u'h': 405, u'resize': u'fit', u'w': 720},
#        u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'https://t.co/Wfvd3rm5qJ'}]},
#    u'favorite_count': 1739,
#    u'favorited': False,
#    u'filter_level': u'low',
#    u'geo': None,
#    u'id': 949724841984319489,
#    u'id_str': u'949724841984319489',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': True,
#    u'quote_count': 484,
#    u'reply_count': 139,
#    u'retweet_count': 1908,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'I knew this country was rubbish when we gave a man of the match 5GB of data https://t.co/Wfvd3rm5qJ',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Jan 25 21:32:20 +0000 2010',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Faithful black man.\nArsenal Football Club fan.\nEmail: tokyodp@gmail.com',
#     u'favourites_count': 432,
#     u'follow_request_sent': None,
#     u'followers_count': 35038,
#     u'following': None,
#     u'friends_count': 1683,
#     u'geo_enabled': True,
#     u'id': 108411936,
#     u'id_str': u'108411936',
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 160,
#     u'location': u'Eastrand',
#     u'name': u'Trevor',
#     u'notifications': None,
#     u'profile_background_color': u'3B94D9',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000028623551/cbcd732a0adc83a672d734007182e54b.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000028623551/cbcd732a0adc83a672d734007182e54b.jpeg',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/108411936/1512288396',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/949708444306694144/aw7NgTCF_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/949708444306694144/aw7NgTCF_normal.jpg',
#     u'profile_link_color': u'ABB8C2',
#     u'profile_sidebar_border_color': u'53AB8D',
#     u'profile_sidebar_fill_color': u'291C0D',
#     u'profile_text_color': u'53AB8D',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Tokyo_Trev',
#     u'statuses_count': 164735,
#     u'time_zone': u'Pretoria',
#     u'translator_type': u'none',
#     u'url': u'https://webfluential.com/Tokyo_Trev',
#     u'utc_offset': 7200,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u'RT @Tokyo_Trev: I knew this country was rubbish when we gave a man of the match 5GB of data https://t.co/Wfvd3rm5qJ',
#   u'timestamp_ms': u'1515311917132',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Tue Jul 10 09:47:51 +0000 2012',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"Arsenal Fan #AFC #Football | \u2665\nLoves Music & Movies | \u2665 \nRandom RT'r! \nUse To Manage Events! \U0001f602",
#    u'favourites_count': 42301,
#    u'follow_request_sent': None,
#    u'followers_count': 1537,
#    u'following': None,
#    u'friends_count': 470,
#    u'geo_enabled': True,
#    u'id': 631851160,
#    u'id_str': u'631851160',
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 49,
#    u'location': u'Petersham, New South Wales',
#    u'name': u'Priyan\u0915\u093e \u0930\u093e\u090a\u0924',
#    u'notifications': None,
#    u'profile_background_color': u'1A1B1F',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/631851160/1508178700',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/940671374158282752/5r81j-N__normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/940671374158282752/5r81j-N__normal.jpg',
#    u'profile_link_color': u'CF232C',
#    u'profile_sidebar_border_color': u'181A1E',
#    u'profile_sidebar_fill_color': u'252429',
#    u'profile_text_color': u'666666',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'PriyaRaut_AFC',
#    u'statuses_count': 58236,
#    u'time_zone': u'Sydney',
#    u'translator_type': u'none',
#    u'url': u'http://www.haveyoueverseentottenhamwintheleague.com/',
#    u'utc_offset': 39600,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:39 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/gemhumor/statu\u2026',
#      u'expanded_url': u'https://twitter.com/gemhumor/status/949762013265195010',
#      u'indices': [50, 73],
#      u'url': u'https://t.co/l0u3U3Ol4W'}],
#    u'user_mentions': [{u'id': 3218903240,
#      u'id_str': u'3218903240',
#      u'indices': [3, 9],
#      u'name': u'zander',
#      u'screen_name': u'finah'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913155483844610,
#   u'id_str': u'949913155483844610',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': True,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'quote_count': 0,
#   u'quoted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 06 21:58:04 +0000 2018',
#    u'display_text_range': [0, 140],
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/949762013265195010',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/QaAofkX2dS'}],
#     u'user_mentions': []},
#    u'extended_tweet': {u'display_text_range': [0, 129],
#     u'entities': {u'hashtags': [],
#      u'media': [{u'display_url': u'pic.twitter.com/aTs99QX6PH',
#        u'expanded_url': u'https://twitter.com/gemhumor/status/949762013265195010/photo/1',
#        u'id': 949762003781877762,
#        u'id_str': u'949762003781877762',
#        u'indices': [130, 153],
#        u'media_url': u'http://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#        u'media_url_https': u'https://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#        u'sizes': {u'large': {u'h': 465, u'resize': u'fit', u'w': 620},
#         u'medium': {u'h': 465, u'resize': u'fit', u'w': 620},
#         u'small': {u'h': 465, u'resize': u'fit', u'w': 620},
#         u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#        u'type': u'photo',
#        u'url': u'https://t.co/aTs99QX6PH'}],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': []},
#     u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/aTs99QX6PH',
#        u'expanded_url': u'https://twitter.com/gemhumor/status/949762013265195010/photo/1',
#        u'id': 949762003781877762,
#        u'id_str': u'949762003781877762',
#        u'indices': [130, 153],
#        u'media_url': u'http://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#        u'media_url_https': u'https://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#        u'sizes': {u'large': {u'h': 465, u'resize': u'fit', u'w': 620},
#         u'medium': {u'h': 465, u'resize': u'fit', u'w': 620},
#         u'small': {u'h': 465, u'resize': u'fit', u'w': 620},
#         u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#        u'type': u'photo',
#        u'url': u'https://t.co/aTs99QX6PH'}]},
#     u'full_text': u'A single sperm has 37.5MB of DNA information in it. That means that a normal ejaculation represents a data transfer of 1,587.5TB. https://t.co/aTs99QX6PH'},
#    u'favorite_count': 822,
#    u'favorited': False,
#    u'filter_level': u'low',
#    u'geo': None,
#    u'id': 949762013265195010,
#    u'id_str': u'949762013265195010',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'quote_count': 318,
#    u'reply_count': 42,
#    u'retweet_count': 385,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'A single sperm has 37.5MB of DNA information in it. That means that a normal ejaculation represents a data transfer\u2026 https://t.co/QaAofkX2dS',
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Jul 05 06:10:04 +0000 2016',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'my name is longer than your dick',
#     u'favourites_count': 82230,
#     u'follow_request_sent': None,
#     u'followers_count': 5307,
#     u'following': None,
#     u'friends_count': 38,
#     u'geo_enabled': False,
#     u'id': 750210113164697601,
#     u'id_str': u'750210113164697601',
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 122,
#     u'location': None,
#     u'name': u'gem city',
#     u'notifications': None,
#     u'profile_background_color': u'F5F8FA',
#     u'profile_background_image_url': u'',
#     u'profile_background_image_url_https': u'',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/750210113164697601/1507010931',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/915096282389024768/2GuYSiLe_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/915096282389024768/2GuYSiLe_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'gemhumor',
#     u'statuses_count': 50,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': u'http://instagram.com/gemhumor',
#     u'utc_offset': None,
#     u'verified': False}},
#   u'quoted_status_id': 949762013265195010,
#   u'quoted_status_id_str': u'949762013265195010',
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 06 21:58:40 +0000 2018',
#    u'display_text_range': [0, 38],
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/gemhumor/statu\u2026',
#       u'expanded_url': u'https://twitter.com/gemhumor/status/949762013265195010',
#       u'indices': [39, 62],
#       u'url': u'https://t.co/l0u3U3Ol4W'}],
#     u'user_mentions': []},
#    u'favorite_count': 41490,
#    u'favorited': False,
#    u'filter_level': u'low',
#    u'geo': None,
#    u'id': 949762165216501760,
#    u'id_str': u'949762165216501760',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': True,
#    u'lang': u'en',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'quote_count': 292,
#    u'quoted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 06 21:58:04 +0000 2018',
#     u'display_text_range': [0, 140],
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/949762013265195010',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/QaAofkX2dS'}],
#      u'user_mentions': []},
#     u'extended_tweet': {u'display_text_range': [0, 129],
#      u'entities': {u'hashtags': [],
#       u'media': [{u'display_url': u'pic.twitter.com/aTs99QX6PH',
#         u'expanded_url': u'https://twitter.com/gemhumor/status/949762013265195010/photo/1',
#         u'id': 949762003781877762,
#         u'id_str': u'949762003781877762',
#         u'indices': [130, 153],
#         u'media_url': u'http://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#         u'media_url_https': u'https://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#         u'sizes': {u'large': {u'h': 465, u'resize': u'fit', u'w': 620},
#          u'medium': {u'h': 465, u'resize': u'fit', u'w': 620},
#          u'small': {u'h': 465, u'resize': u'fit', u'w': 620},
#          u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#         u'type': u'photo',
#         u'url': u'https://t.co/aTs99QX6PH'}],
#       u'symbols': [],
#       u'urls': [],
#       u'user_mentions': []},
#      u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/aTs99QX6PH',
#         u'expanded_url': u'https://twitter.com/gemhumor/status/949762013265195010/photo/1',
#         u'id': 949762003781877762,
#         u'id_str': u'949762003781877762',
#         u'indices': [130, 153],
#         u'media_url': u'http://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#         u'media_url_https': u'https://pbs.twimg.com/media/DS47gqiVAAI1kpk.jpg',
#         u'sizes': {u'large': {u'h': 465, u'resize': u'fit', u'w': 620},
#          u'medium': {u'h': 465, u'resize': u'fit', u'w': 620},
#          u'small': {u'h': 465, u'resize': u'fit', u'w': 620},
#          u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#         u'type': u'photo',
#         u'url': u'https://t.co/aTs99QX6PH'}]},
#      u'full_text': u'A single sperm has 37.5MB of DNA information in it. That means that a normal ejaculation represents a data transfer of 1,587.5TB. https://t.co/aTs99QX6PH'},
#     u'favorite_count': 822,
#     u'favorited': False,
#     u'filter_level': u'low',
#     u'geo': None,
#     u'id': 949762013265195010,
#     u'id_str': u'949762013265195010',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'quote_count': 318,
#     u'reply_count': 42,
#     u'retweet_count': 385,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     u'text': u'A single sperm has 37.5MB of DNA information in it. That means that a normal ejaculation represents a data transfer\u2026 https://t.co/QaAofkX2dS',
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Tue Jul 05 06:10:04 +0000 2016',
#      u'default_profile': True,
#      u'default_profile_image': False,
#      u'description': u'my name is longer than your dick',
#      u'favourites_count': 82230,
#      u'follow_request_sent': None,
#      u'followers_count': 5307,
#      u'following': None,
#      u'friends_count': 38,
#      u'geo_enabled': False,
#      u'id': 750210113164697601,
#      u'id_str': u'750210113164697601',
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 122,
#      u'location': None,
#      u'name': u'gem city',
#      u'notifications': None,
#      u'profile_background_color': u'F5F8FA',
#      u'profile_background_image_url': u'',
#      u'profile_background_image_url_https': u'',
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/750210113164697601/1507010931',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/915096282389024768/2GuYSiLe_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/915096282389024768/2GuYSiLe_normal.jpg',
#      u'profile_link_color': u'1DA1F2',
#      u'profile_sidebar_border_color': u'C0DEED',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'gemhumor',
#      u'statuses_count': 50,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': u'http://instagram.com/gemhumor',
#      u'utc_offset': None,
#      u'verified': False}},
#    u'quoted_status_id': 949762013265195010,
#    u'quoted_status_id_str': u'949762013265195010',
#    u'reply_count': 118,
#    u'retweet_count': 13725,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'that\u2019s a lot of information to swallow https://t.co/l0u3U3Ol4W',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon May 18 03:32:56 +0000 2015',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'press the follow button i dare you',
#     u'favourites_count': 46503,
#     u'follow_request_sent': None,
#     u'followers_count': 98263,
#     u'following': None,
#     u'friends_count': 534,
#     u'geo_enabled': True,
#     u'id': 3218903240,
#     u'id_str': u'3218903240',
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 1853,
#     u'location': u'snapchat: zandirt',
#     u'name': u'zander',
#     u'notifications': None,
#     u'profile_background_color': u'000000',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/3218903240/1507964626',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/919041856037560320/WWe06ALw_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/919041856037560320/WWe06ALw_normal.jpg',
#     u'profile_link_color': u'234E20',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'finah',
#     u'statuses_count': 22701,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'translator_type': u'regular',
#     u'url': u'http://Instagram.com/zandirt',
#     u'utc_offset': -28800,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @finah: that\u2019s a lot of information to swallow https://t.co/l0u3U3Ol4W',
#   u'timestamp_ms': u'1515311919457',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sat May 31 11:22:28 +0000 2014',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'emotionally slutty',
#    u'favourites_count': 32784,
#    u'follow_request_sent': None,
#    u'followers_count': 443,
#    u'following': None,
#    u'friends_count': 199,
#    u'geo_enabled': True,
#    u'id': 2537272561,
#    u'id_str': u'2537272561',
#    u'is_translator': False,
#    u'lang': u'en-gb',
#    u'listed_count': 1,
#    u'location': None,
#    u'name': u'uHM',
#    u'notifications': None,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/602073787689869312/UozkB2xA.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/602073787689869312/UozkB2xA.png',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2537272561/1515263942',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/949711666266062848/JcrxGpTa_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/949711666266062848/JcrxGpTa_normal.jpg',
#    u'profile_link_color': u'ABB8C2',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ityagirlhoennah',
#    u'statuses_count': 31846,
#    u'time_zone': u'Beijing',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': 28800,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:39 +0000 2018',
#   u'display_text_range': [11, 140],
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#      u'expanded_url': u'https://twitter.com/i/web/status/949913156800757760',
#      u'indices': [117, 140],
#      u'url': u'https://t.co/b6bYfY8S2F'}],
#    u'user_mentions': [{u'id': 418500784,
#      u'id_str': u'418500784',
#      u'indices': [0, 10],
#      u'name': u'Ander.',
#      u'screen_name': u'EzamYusof'}]},
#   u'extended_tweet': {u'display_text_range': [11, 291],
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'umobile.response.lithium.com/portal/convers\u2026',
#       u'expanded_url': u'https://umobile.response.lithium.com/portal/conversation/4382657',
#       u'indices': [268, 291],
#       u'url': u'https://t.co/BATsPSuTEO'}],
#     u'user_mentions': [{u'id': 418500784,
#       u'id_str': u'418500784',
#       u'indices': [0, 10],
#       u'name': u'Ander.',
#       u'screen_name': u'EzamYusof'}]},
#    u'full_text': u'@EzamYusof Hai, sudahkah anda menyemak baki data anda? Sila ambil perhatian bahawa kelajuan data akan diperlahankan jika kuota telah digunakan sepenuhnya. Dalam pada itu, kami hargai jika anda dapat DM kepada kami nombor telefon, jenis rangkaian yg terpapar, alama... https://t.co/BATsPSuTEO'},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913156800757760,
#   u'id_str': u'949913156800757760',
#   u'in_reply_to_screen_name': u'EzamYusof',
#   u'in_reply_to_status_id': 949305459386679297,
#   u'in_reply_to_status_id_str': u'949305459386679297',
#   u'in_reply_to_user_id': 418500784,
#   u'in_reply_to_user_id_str': u'418500784',
#   u'is_quote_status': False,
#   u'lang': u'in',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'quote_count': 0,
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="https://www.lithium.com" rel="nofollow">Lithium Tech.</a>',
#   u'text': u'@EzamYusof Hai, sudahkah anda menyemak baki data anda? Sila ambil perhatian bahawa kelajuan data akan diperlahankan\u2026 https://t.co/b6bYfY8S2F',
#   u'timestamp_ms': u'1515311919771',
#   u'truncated': True,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Oct 17 02:29:39 +0000 2013',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'U Mobile is a data-centric, award-winning telco. We constantly disrupt the status quo to give what customers want. Their passions drive our UNLIMITED IDEAS.',
#    u'favourites_count': 501,
#    u'follow_request_sent': None,
#    u'followers_count': 120611,
#    u'following': None,
#    u'friends_count': 1452,
#    u'geo_enabled': True,
#    u'id': 1965926702,
#    u'id_str': u'1965926702',
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 70,
#    u'location': u'Malaysia',
#    u'name': u'U Mobile',
#    u'notifications': None,
#    u'profile_background_color': u'F88217',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000169565613/9_6RT1tW.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000169565613/9_6RT1tW.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1965926702/1511920760',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000607520173/2e58b5c468291ef16b38a36b79a993e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000607520173/2e58b5c468291ef16b38a36b79a993e3_normal.jpeg',
#    u'profile_link_color': u'F88217',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'umobile',
#    u'statuses_count': 56575,
#    u'time_zone': u'Kuala Lumpur',
#    u'translator_type': u'none',
#    u'url': u'http://www.u.com.my',
#    u'utc_offset': 28800,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:40 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913158281342976,
#   u'id_str': u'949913158281342976',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': False,
#   u'lang': u'tl',
#   u'place': None,
#   u'quote_count': 0,
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'hayop optus ambilis nyo kumain ng data kurakot',
#   u'timestamp_ms': u'1515311920124',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Mar 30 06:07:14 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"If you have not watched Jimin's Perfect Man fancam, then you have not lived || \ub9c8\uc9c0\ub9c9\ucc98\ub7fc",
#    u'favourites_count': 5605,
#    u'follow_request_sent': None,
#    u'followers_count': 109,
#    u'following': None,
#    u'friends_count': 272,
#    u'geo_enabled': False,
#    u'id': 274370677,
#    u'id_str': u'274370677',
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 1,
#    u'location': u'MNL',
#    u'name': u'\ub098\uc57c,  Athena Aji3',
#    u'notifications': None,
#    u'profile_background_color': u'DBE9ED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/622632407955406848/rCwC-DPq.jpg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/622632407955406848/rCwC-DPq.jpg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/274370677/1512631273',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/940209296943362048/1I_y9TIv_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/940209296943362048/1I_y9TIv_normal.jpg',
#    u'profile_link_color': u'89C9FA',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'E6F6F9',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ttekkittekki',
#    u'statuses_count': 8605,
#    u'time_zone': u'Perth',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': 28800,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:40 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 165085226,
#      u'id_str': u'165085226',
#      u'indices': [3, 17],
#      u'name': u'Shakeel Ahmad',
#      u'screen_name': u'Ahmad_Shakeel'}]},
#   u'favorite_count': 0,
# ...
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Shahid1608',
#    u'statuses_count': 6628,
#    u'time_zone': u'Mumbai',
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': 19800,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:40 +0000 2018',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 63168638,
#      u'id_str': u'63168638',
#      u'indices': [0, 12],
#      u'name': u'Tommie Christiaan',
#      u'screen_name': u'TommieChris'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913161192361984,
#   u'id_str': u'949913161192361984',
#   u'in_reply_to_screen_name': u'TommieChris',
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': 63168638,
#   u'in_reply_to_user_id_str': u'63168638',
#   u'is_quote_status': False,
#   u'lang': u'nl',
#   u'place': None,
#   u'quote_count': 0,
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u'@TommieChris zijn er dagen/data waarop Jij vast speelt??!',
#   u'timestamp_ms': u'1515311920818',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sat Oct 13 21:39:17 +0000 2012',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': None,
#    u'favourites_count': 832,
#    u'follow_request_sent': None,
#    u'followers_count': 117,
#    u'following': None,
#    u'friends_count': 739,
#    u'geo_enabled': True,
#    u'id': 878743908,
#    u'id_str': u'878743908',
#    u'is_translator': False,
#    u'lang': u'nl',
#    u'listed_count': 10,
#    u'location': u'Heerhugowaard ',
#    u'name': u'diny de lange',
#    u'notifications': None,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/461038582481055744/sMe-ycsY_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/461038582481055744/sMe-ycsY_normal.jpeg',
#    u'profile_link_color': u'1DA1F2',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'dmgdelange',
#    u'statuses_count': 3096,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Sun Jan 07 07:58:40 +0000 2018',
#   u'entities': {u'hashtags': [{u'indices': [20, 32], u'text': u'NiechJedzie'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'twitter.com/tomaszsiemonia\u2026',
#      u'expanded_url': u'https://twitter.com/tomaszsiemoniak/status/949714337761038337',
#      u'indices': [33, 56],
#      u'url': u'https://t.co/kVcR8xwcvH'}],
#    u'user_mentions': [{u'id': 2549508198,
#      u'id_str': u'2549508198',
#      u'indices': [3, 18],
#      u'name': u'FanTomas Szary',
#      u'screen_name': u'T_Stanislawski'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'filter_level': u'low',
#   u'geo': None,
#   u'id': 949913161842520064,
#   u'id_str': u'949913161842520064',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'is_quote_status': True,
#   u'lang': u'und',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'quote_count': 0,
#   u'quoted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 06 18:48:37 +0000 2018',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/949714337761038337',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/DK7xizFgoh'}],
#     u'user_mentions': []},
#    u'extended_tweet': {u'display_text_range': [0, 278],
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': []},
#     u'full_text': u'Tyle szumu wok\xf3\u0142 "zaproszenia Macierewicza do Bia\u0142ego Domu", a podawana data 17 stycznia wg dziennikarskich waszyngto\u0144skich \u017ar\xf3de\u0142 ju\u017c nieaktualna. Amerykanie nie chc\u0105, aby zaproszenie do doradcy prezydenta USA by\u0142o wykorzystywane jako element rekonstrukcyjnych rozgrywek w PiS.'},
#    u'favorite_count': 321,
#    u'favorited': False,
#    u'filter_level': u'low',
#    u'geo': None,
#    u'id': 949714337761038337,
#    u'id_str': u'949714337761038337',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'pl',
#    u'place': None,
#    u'quote_count': 7,
#    u'reply_count': 24,
#    u'retweet_count': 106,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'Tyle szumu wok\xf3\u0142 "zaproszenia Macierewicza do Bia\u0142ego Domu", a podawana data 17 stycznia wg dziennikarskich waszyng\u2026 https://t.co/DK7xizFgoh',
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Aug 11 16:32:46 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'pose\u0142 na Sejm, wiceprzewodnicz\u0105cy Platformy Obywatelskiej',
#     u'favourites_count': 26074,
#     u'follow_request_sent': None,
#     u'followers_count': 74949,
#     u'following': None,
#     u'friends_count': 1634,
#     u'geo_enabled': True,
#     u'id': 64759001,
#     u'id_str': u'64759001',
#     u'is_translator': False,
#     u'lang': u'pl',
#     u'listed_count': 317,
#     u'location': u'Wa\u0142brzych, Dolno\u015bl\u0105skie',
#     u'name': u'Tomasz Siemoniak',
#     u'notifications': None,
#     u'profile_background_color': u'EBEBEB',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme7/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme7/bg.gif',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/64759001/1451920206',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/948797534671196160/HPesp5MZ_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/948797534671196160/HPesp5MZ_normal.jpg',
#     u'profile_link_color': u'990000',
#     u'profile_sidebar_border_color': u'DFDFDF',
#     u'profile_sidebar_fill_color': u'F3F3F3',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'TomaszSiemoniak',
#     u'statuses_count': 27305,
#     u'time_zone': u'Warsaw',
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': 3600,
#     u'verified': False}},
#   u'quoted_status_id': 949714337761038337,
#   u'quoted_status_id_str': u'949714337761038337',
#   u'reply_count': 0,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 06 20:00:45 +0000 2018',
#    u'display_text_range': [0, 12],
#    u'entities': {u'hashtags': [{u'indices': [0, 12], u'text': u'NiechJedzie'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/tomaszsiemonia\u2026',
#       u'expanded_url': u'https://twitter.com/tomaszsiemoniak/status/949714337761038337',
#       u'indices': [13, 36],
#       u'url': u'https://t.co/kVcR8xwcvH'}],
#     u'user_mentions': []},
#    u'favorite_count': 15,
#    u'favorited': False,
#    u'filter_level': u'low',
#    u'geo': None,
#    u'id': 949732488800276480,
#    u'id_str': u'949732488800276480',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': True,
#    u'lang': u'und',
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'quote_count': 0,
#    u'quoted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 06 18:48:37 +0000 2018',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/9\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/949714337761038337',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/DK7xizFgoh'}],
#      u'user_mentions': []},
#     u'extended_tweet': {u'display_text_range': [0, 278],
#      u'entities': {u'hashtags': [],
#       u'symbols': [],
#       u'urls': [],
#       u'user_mentions': []},
#      u'full_text': u'Tyle szumu wok\xf3\u0142 "zaproszenia Macierewicza do Bia\u0142ego Domu", a podawana data 17 stycznia wg dziennikarskich waszyngto\u0144skich \u017ar\xf3de\u0142 ju\u017c nieaktualna. Amerykanie nie chc\u0105, aby zaproszenie do doradcy prezydenta USA by\u0142o wykorzystywane jako element rekonstrukcyjnych rozgrywek w PiS.'},
#     u'favorite_count': 321,
#     u'favorited': False,
#     u'filter_level': u'low',
#     u'geo': None,
#     u'id': 949714337761038337,
#     u'id_str': u'949714337761038337',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'pl',
#     u'place': None,
#     u'quote_count': 7,
#     u'reply_count': 24,
#     u'retweet_count': 106,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     u'text': u'Tyle szumu wok\xf3\u0142 "zaproszenia Macierewicza do Bia\u0142ego Domu", a podawana data 17 stycznia wg dziennikarskich waszyng\u2026 https://t.co/DK7xizFgoh',
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Tue Aug 11 16:32:46 +0000 2009',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'pose\u0142 na Sejm, wiceprzewodnicz\u0105cy Platformy Obywatelskiej',
#      u'favourites_count': 26074,
#      u'follow_request_sent': None,
#      u'followers_count': 74949,
#      u'following': None,
#      u'friends_count': 1634,
#      u'geo_enabled': True,
#      u'id': 64759001,
#      u'id_str': u'64759001',
#      u'is_translator': False,
#      u'lang': u'pl',
#      u'listed_count': 317,
#      u'location': u'Wa\u0142brzych, Dolno\u015bl\u0105skie',
#      u'name': u'Tomasz Siemoniak',
#      u'notifications': None,
#      u'profile_background_color': u'EBEBEB',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme7/bg.gif',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme7/bg.gif',
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/64759001/1451920206',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/948797534671196160/HPesp5MZ_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/948797534671196160/HPesp5MZ_normal.jpg',
#      u'profile_link_color': u'990000',
#      u'profile_sidebar_border_color': u'DFDFDF',
#      u'profile_sidebar_fill_color': u'F3F3F3',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'TomaszSiemoniak',
#      u'statuses_count': 27305,
#      u'time_zone': u'Warsaw',
#      u'translator_type': u'none',
#      u'url': None,
#      u'utc_offset': 3600,
#      u'verified': False}},
#    u'quoted_status_id': 949714337761038337,
#    u'quoted_status_id_str': u'949714337761038337',
#    u'reply_count': 0,
#    u'retweet_count': 6,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'#NiechJedzie https://t.co/kVcR8xwcvH',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Jun 06 08:11:59 +0000 2014',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'AntyKaczyzm mam w DNA. Prawi trolle m\xf3wi\u0105 - "twardy Ubek" \U0001f602  #CzasRozumu #dekalogwolnosci #RacjonalnaPolska #JaSzaryObywatel',
#     u'favourites_count': 31892,
#     u'follow_request_sent': None,
#     u'followers_count': 5382,
#     u'following': None,
#     u'friends_count': 3339,
#     u'geo_enabled': True,
#     u'id': 2549508198,
#     u'id_str': u'2549508198',
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 20,
#     u'location': None,
#     u'name': u'FanTomas Szary',
#     u'notifications': None,
#     u'profile_background_color': u'000000',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2549508198/1497390199',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/948824966631493638/vxdkW9mN_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/948824966631493638/vxdkW9mN_normal.jpg',
#     u'profile_link_color': u'1B95E0',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'T_Stanislawski',
#     u'statuses_count': 35615,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': -28800,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   u'text': u'RT @T_Stanislawski: #NiechJedzie https://t.co/kVcR8xwcvH',
#   u'timestamp_ms': u'1515311920973',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Feb 22 19:05:08 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': None,
#    u'favourites_count': 21635,
#    u'follow_request_sent': None,
#    u'followers_count': 239,
#    u'following': None,
#    u'friends_count': 943,
#    u'geo_enabled': False,
#    u'id': 116517689,
#    u'id_str': u'116517689',
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 0,
#    u'location': u'Torun',
#    u'name': u'adam ostrowskiresult',
#    u'notifications': None,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/116517689/1480415107',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/803545516848087041/dYA7pfo4_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/803545516848087041/dYA7pfo4_normal.jpg',
#    u'profile_link_color': u'1B95E0',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'tamtem155',
#    u'statuses_count': 4631,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}}]

# %%
top_hashtags = Counter(hashtag['text'].lower()
                      for tweet in tweets
                      for hashtag in tweet["entities"]["hashtags"])

# %%
print top_hashtags.most_common(5)
# Out:
# [(u'bigdata', 3), (u'honorview10', 2), (u'tribune', 2), (u'iot', 2), (u'datascience', 2)]
